# %% [markdown]
# ## Evidence status
#
# The earlier precision-at-10 figures are withdrawn because this repository does not link them to an approved dataset build, split, seed, and reproducible run receipt. Saved outputs are historical artifacts, not current performance evidence. Reproduce and document an approved evaluation before publishing any metric.

# %% [markdown]
# # Week 8 — Tell the Story
#
# ## Five-minute demo outline
#
# **0:00–0:35 — Question.** Content teams cannot inspect every page. Which pages should enter a first human discoverability review?
#
# **0:35–1:25 — Data and safety.** Use public-safe aggregate Search Console fields from the FlyRank internship warehouse. Exclude client names, domains, URLs, credentials, private queries, identifiers as features, future inputs, and label-derived fields.
#
# **1:25–2:20 — Method.** Apply the transparent baseline `impressions × (1 − CTR)` to pages with at least 100 impressions and average position from 5 to 20. No reproducible metric comparison is currently claimed because approved dataset, split, seed, and run provenance are not linked.
#
# **2:20–3:15 — Evidence boundary.** Explain that no performance metric is presented until an approved dataset build, split, seed, and run receipt are linked.
#
# **3:15–4:05 — Honest result.** No performance result is claimed. This does not prove that editing a page causes higher rankings or traffic.
#
# **4:05–5:00 — Recommendation.** Review high-impression, mid-position, under-captured-click pages first; then check query intent, SERP features, volatility, and technical context before changing a title or description.
#
# ## Shareable cuts
#
# ### Social post
#
# I designed a human review queue using aggregate search-performance signals and documented cases where the right answer is monitor, do not edit. No comparative performance claim is presented until the dataset, split, and run provenance are reproducibly linked: https://minagayid.github.io/flyrank/capstone/
#
# ### Employer-facing summary
#
# I designed a content-opportunity scoring workflow using aggregate search-performance signals for a human review queue. No comparative performance claim is currently made: the earlier precision-at-10 figures lack linked dataset, split, seed, and run provenance and have been withdrawn.
